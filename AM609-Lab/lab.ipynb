# %% [markdown]
# 1. wap :
#     a - binary to deciman
#     b. - decimal to binary
#     c - hex to decimal
#     d - decimal to hex

# %%
def binary_to_deciman(num:str) -> float:
    """
    Convert the given input string to it's binary representation. 
    The number can be integers as well as decimals. 
    """
    
    #validation 
    for digit in num:
        if not(int(digit) == 1 or int(digit) == 0 ):
            print("invalid binary input")
            break
        
            
        
        




print(binary_to_deciman("111"))
# Out:
# Input is a binary number
# invalid binary inpout
# Input is a binary number
# None

# %%
print(binary_to_deciman("111"))
# Out:
# invalid binary inpout
# invalid binary inpout
# invalid binary inpout
# 0
