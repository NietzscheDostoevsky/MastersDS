# %%
import tensorflow as tf
import keras
# Out:
# 2026-01-11 07:07:59.291424: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-11 07:07:59.327388: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-11 07:08:00.194296: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
def print_gpu_info():
    """Prints GPU information using TensorFlow."""
    gpus = tf.config.list_physical_devices('GPU')
    if not gpus:
        print("CUDA is not available.")
        return

    gpu = gpus[0]

    try:
        details = tf.config.experimental.get_device_details(gpu)
        
        print(f"GPU : {details.get('device_name', 'Unknown')}")
        
        cc = details.get('compute_capability')
        if cc:
            print(f"GPU capability: {cc}")
            
    except AttributeError:
        print("Your TensorFlow version is too old to fetch device details.")

    print("-" * 30)

    # !nvidia-smi

print_gpu_info()
# Out:
# GPU : NVIDIA GeForce RTX 3060
# GPU capability: (8, 6)
# ------------------------------
# Sun Jan 11 07:09:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060        Off |   00000000:01:00.0  On |                  N/A |
# |  0%   49C    P8             17W /  170W |     806MiB /  12288MiB |     24%      Default |
# ...

# %%
input = keras.Input(shape=29)
x = keras.layers.Dense(16, activation="relu")(input)
out = keras.layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(input, out)
