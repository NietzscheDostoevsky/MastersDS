# %% [markdown]
# ## Setting up environment for developement.
#
# ### Install Libraries
# ### Perform smoke test on the environment

# %% [markdown]
# ### Installing the libraries, if needed

# %%
import matplotlib
import sympy
# Install core packages using the %conda magic command

# %conda install numpy scipy matplotlib ipykernel -c conda-forge -y
# %conda install sympy
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/saurabh-singh/miniconda3/envs/NumericalLA
#
#   added / updated specs:
#     - sympy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gmp-6.3.0                  |       h6a678d5_0         608 KB
#     gmpy2-2.2.1                |  py313h5eee18b_0         258 KB
#     mpc-1.3.1                  |       h5eee18b_0         129 KB
#     mpfr-4.2.1                 |       h5eee18b_0         821 KB
#     mpmath-1.3.0               |  py313h06a4308_0        1000 KB
#     sympy-1.14.0               |  py313h06a4308_0        15.3 MB
#     ------------------------------------------------------------
#                                            Total:        18.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   gmp                pkgs/main/linux-64::gmp-6.3.0-h6a678d5_0
#   gmpy2              pkgs/main/linux-64::gmpy2-2.2.1-py313h5eee18b_0
#   mpc                pkgs/main/linux-64::mpc-1.3.1-h5eee18b_0
#   mpfr               pkgs/main/linux-64::mpfr-4.2.1-h5eee18b_0
#   mpmath             pkgs/main/linux-64::mpmath-1.3.0-py313h06a4308_0
#   sympy              pkgs/main/linux-64::sympy-1.14.0-py313h06a4308_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2025.10.5~ --> pkgs/main/linux-64::certifi-2025.10.5-py313h06a4308_0
#
#
#
# Downloading and Extracting Packages:
# gmp-6.3.0            | 608 KB    |                                       |   0%
# gmpy2-2.2.1          | 258 KB    |                                       |   0%
#
# mpfr-4.2.1           | 821 KB    |                                       |   0%
#
#
# mpc-1.3.1            | 129 KB    |                                       |   0%
#
#
#
# mpmath-1.3.0         | 1000 KB   |                                       |   0%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   |                                       |   0%
#
#
# mpc-1.3.1            | 129 KB    | ####5                                 |  12%
#
#
# mpc-1.3.1            | 129 KB    | ##################################### | 100%
# gmpy2-2.2.1          | 258 KB    | ##2                                   |   6%
#
# mpfr-4.2.1           | 821 KB    | 7                                     |   2%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   |                                       |   0%
# gmpy2-2.2.1          | 258 KB    | ##################################### | 100%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ######3                               |  17%
#
#
#
# mpmath-1.3.0         | 1000 KB   | 5                                     |   2%
#
# gmp-6.3.0            | 608 KB    | #################5                    |  47%
#
# mpfr-4.2.1           | 821 KB    | ##################7                   |  51%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ############4                         |  34%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ###############3                      |  42%
#
#
#
# mpmath-1.3.0         | 1000 KB   | ####1                                 |  11%
#
#
#
# mpmath-1.3.0         | 1000 KB   | #######6                              |  21%
#
#
#
# mpmath-1.3.0         | 1000 KB   | ###############9                      |  43%
#
#
#
#
# gmp-6.3.0            | 608 KB    | ##################################### | 100%
#
#
#
# mpmath-1.3.0         | 1000 KB   | ####################7                 |  56%
#
#
#
# mpmath-1.3.0         | 1000 KB   | #########################4            |  69%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ###################1                  |  52%
#
# mpfr-4.2.1           | 821 KB    | #########################9            |  70%
#
#
#
# mpmath-1.3.0         | 1000 KB   | ##############################7       |  83%
#
# mpfr-4.2.1           | 821 KB    | #################################8    |  92%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ####################4                 |  55%
#
#
#
# mpmath-1.3.0         | 1000 KB   | ###################################5  |  96%
#
#
#
# mpmath-1.3.0         | 1000 KB   | ##################################### | 100%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | #####################8                |  59%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | #######################               |  62%
#
# mpfr-4.2.1           | 821 KB    | ##################################### | 100%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ########################3             |  66%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | #########################4            |  69%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ###########################9          |  76%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | #############################4        |  80%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ##############################7       |  83%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ################################      |  87%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | #################################3    |  90%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ##################################5   |  93%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ###################################8  |  97%
#
#
#
#
# sympy-1.14.0         | 15.3 MB   | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Smoke test on the environment

# %%
import numpy as np
import scipy
import matplotlib
import sympy as sp

# Testing numpy
print(f"NumPy version : {np.__version__}")
print(f"Scipy version : {scipy.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print(f"SymPy version : {sp.__version__}")
# Out:
# NumPy version : 2.3.4
# Scipy version : 1.16.3
# Matplotlib version: 3.10.7
# SymPy version : 1.14.0
