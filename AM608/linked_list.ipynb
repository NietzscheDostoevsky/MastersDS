# %%
# Reversing a portion of the linked list. 

class Node:
    def __init__(self, value, next_node):
        self.val = value
        self.next = next_node

def reverse_between(head, m, n):
    if not head or m == n:
        return head

    dummy = Node(0)
